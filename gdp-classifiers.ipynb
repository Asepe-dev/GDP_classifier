# %%
country = input("Enter country: ")
gdp = float(input("Enter GDP per capita: "))

if gdp < 2000:
    category = "Low income"
elif gdp < 10000:
    category = "Middle income"
else:
    category = "High income"

print(country, "is a", category, "country")
# Out:
# Enter country:  Nigeria
# Enter GDP per capita:  20000
# Nigeria is a High income country
